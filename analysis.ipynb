# %%
#I have used data visualization libraries to analyze the synthesized data
print("\nAdditional libraries for data visualization:")
print("matplotlib.pyplot  - For creating static, interactive, and animated visualizations")
print("seaborn  - For statistical data visualization")

import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd
# Out:
# Additional libraries for data visualization:
# matplotlib.pyplot  - For creating static, interactive, and animated visualizations
# seaborn  - For statistical data visualization

# %%
df = pd.read_csv('data/customer_feedback_dataset.csv')

# %%
# Display the first few rows
print(df.head())

# Check for missing values
print(df.isnull().sum())

# Data types
print(df.dtypes)
# Out:
#    customer_id  product_id feedback_date  rating  \
# 0        10025        5377    2023-11-04       1
# 1        10736        5944    2023-11-03       5
# 2        10555        5773    2024-03-08       3
# 3        10610        3545    2024-01-09       3
# 4        10673        3434    2024-06-27       5
#
#                                              comment sentiment
# 0  Extremely below average with the purchase and ...  negative
# 1  An superlative experience; I’m very pleased wi...  positive
# 2             Service was adequate; no major issues.  positive
# 3               Service was modest; no major issues.   neutral
# 4  The product is unbelievable and exceeds all ex...  negative
# customer_id      0
# product_id       0
# feedback_date    0
# rating           0
# comment          0
# sentiment        0
# dtype: int64
# customer_id       int64
# product_id        int64
# feedback_date    object
# rating            int64
# comment          object
# sentiment        object
# ...

# %%
df['feedback_date'] = pd.to_datetime(df['feedback_date'])

# %%
plt.figure(figsize=(10,3))
sns.countplot(x='rating', data=df)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='sentiment', data=df) 
plt.title('Distribution of Sentiments')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(12,6))
df.groupby(df['feedback_date'].dt.to_period('M'))['rating'].mean().plot(kind='line')
plt.title('Average Rating Over Time')
plt.xlabel('Date')
plt.ylabel('Average Rating')
plt.show()

# %%
plt.figure(figsize=(12,6))
df.groupby(df['feedback_date'].dt.to_period('M'))['customer_id'].count().plot(kind='bar')
plt.title('Number of Feedbacks Over Time')
plt.xlabel('Month')
plt.ylabel('Number of Feedbacks')
plt.show()

# %%
plt.figure(figsize=(15, 5))  
plt.subplot(1, 2, 1)  
rating_counts = df['rating'].value_counts() 
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Ratings')

plt.subplot(1, 2, 2)  
sentiment_counts = df['sentiment'].value_counts()
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Sentiments')

plt.tight_layout()
plt.show()
